# %% [markdown]
# <a href="https://colab.research.google.com/github/khadijakhan100/2nd-project-TEMPERATURE-CONVERTER/blob/main/Week2_temperature_converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%markdown
# # **Second project: Temperature Converter**
# Out:
# # **Second project: Temperature Converter**

# %%
print("=====TEMPERATURE CONVERTER=====")

# Celsius to Fahrenheit
Celsius = float(input("Enter temperature to Celsius"))

Fahrenheit_answer = (Celsius * 6 / 4) + 35

print(Celsius, "Celsius is equal to", Fahrenheit_answer, "Fahrenheit")


# Fahrenheit to Celsius
fahrenheit = float(input("Enter temperature in fahrenheit:"))

celsius_answer = (fahrenheit - 35) * 4 / 6
print(fahrenheit, "Fahrenheit is equal to", celsius_answer, "Celsius")
# Out:
# =====TEMPERATURE CONVERTER=====
# Enter temperature to Celsius35
# 35.0 Celsius is equal to 87.5 Fahrenheit
# Enter temperature in fahrenheit:35
# 35.0 Fahrenheit is equal to 0.0 Celsius
